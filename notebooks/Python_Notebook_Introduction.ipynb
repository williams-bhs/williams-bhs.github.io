# %% [markdown]
# <a href="https://colab.research.google.com/github/williams-bhs/williams-bhs.github.io/blob/main/notebooks/Python_Notebook_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # An Introduction to Python Notebooks
# Python notebooks are a mix of text cells and code cells. This is a text cell. You can edit the text and even write $\LaTeX$ equations:
# $${n \choose r} = \frac{n!}{r!(n-r)!}$$

# %%
# This is a comment in a code cell. Select this cell and run it with [Shift]+[Enter]
x = 25

# %% [markdown]
# Notebooks run an interactive Python environment. The code you ran above created a variable named `x` and set that variable equal to `25`. That value is now stored in the background Python environment. Run the next code cell to see the current value of `x`.

# %%
x

# %% [markdown]
# ## Notebooks are easy to edit, but can lead to problems
# Being able to quickly edit and re-run code cells is what makes notebooks useful. It can also lead to issues when cells are run out of order, or create impossible-to-find bugs when variables are deleted from code but still exist in the background environment. Just be aware that this is only one type of platform.
#
# ## Try writing Python!
# The rest of this document gives examples of funamental Python syntax. Read, run, and edit cells.

# %% [markdown]
# ## Variables, print(), and arithmetic

# %%
# The following variables are an integer, floating point number, and string:
i = 42
f = 3.14
s = "String of characters"

# The print() function prints to the output. Run and edit values then re-run.
print(i)
print(f)
print(s)

# %%
# Basic arithmetic
v1 = 5 + 3
v2 = 6 - 5
v3 = 8 * 7
v4 = 9 / 3
print(v1,v2,v3,v4)

# %%
# Expressions
result = 2 + (5+17)/(4*22)
print(result)

# %%
# The following expression generates an error because someone tried using implicit
# multiplication (not writing * for multiply). Run first, then fix the error.

4(8+3)

# %% [markdown]
# In the code cell below, add a line of code that creates a variable `answer` and assigns it the value $3\times \frac{20+8}{10-6}$. Then print `answer` (it should be 21.0).

# %%
# TODO: Put your code in this cell:

# %% [markdown]
# ## Strings

# %%
# A string of characters is how we store basic text. Note the quotes.
# Fix the code below so there is a space between sentences.
str1 = "This is a string."
str2 = 'Single quotes work also.'
print(str1 + str2)

# %% [markdown]
# ## Lists and indexing

# %%
#

# %% [markdown]
# ## Loops

# %%
# Loops
for i in range(5):
  print("looping...")
  print(i)

# %% [markdown]
# ## Functions

# %%
# The following are very short functions that take some input(s) and might return something.
# When you run this cell, these functions are defined but not used. There is no output.
def square(n):
  return n*n

def addTogether(a,b,c):
  return a+b+c

def makeGreeting(name):
  print("Hello " + name)

# %%
# The following lines of code *call* the functions above and .
print("Four squared is: " + str(square(4)))

x=1
y=2
z=3
print( addTogether(x,y,z) )

me = "Make this your name"
makeGreeting(me)

# %% [markdown]
# ## Data Visualization
# Python has several code *libraries* for working with and visualizing data. Below are examples of basic visualizations. Try editing data values and re-running.
#
# There is a gallery of visualizations online at https://matplotlib.org/stable/gallery/index.html

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [5, 3, 5, 9, 20]

plt.plot(x, y)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Line Chart')
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [10, 25, 18, 30]

plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000) # Generate random data

plt.hist(data, bins=30, edgecolor='black')   # Try changing the number of bins
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y)
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.title('Scatter Plot Example')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {'Group': ['A']*20 + ['B']*20 + ['C']*20,
        'Value': np.random.randn(60)}
df = pd.DataFrame(data)

sns.boxplot(x='Group', y='Value', data=df)
plt.title('Box Plot Example')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = np.random.rand(10, 10) # Random 10x10 matrix

sns.heatmap(data, annot=True, cmap='viridis')
plt.title('Heatmap Example')
plt.show()
