# %% [markdown]
# <a href="https://colab.research.google.com/github/williams-bhs/williams-bhs.github.io/blob/main/notebooks/Exercises_Python_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use this collab to answer the exercises in the Python Introduction from https://williams-bhs.github.io/

# %% [markdown]
# # 1

# %%
from math import sqrt, sin, cos

print("a. Answer = 23")
print( 5 + 18 )   # You put answers in the print statements

print("b. Answer = 13")
print(  )

print("c. Answer = 4.571428571428571")
print(  )

print("d. Answer = 6.4")
print(  )

print("e. Answer = 6.333333333333333")
print(  )

print("f. Answer = 0.4166666666666667")
print(  )

print("g. Answer = 5.0")
print(  )

print("h. Answer = 0.7071067811865476")
print(  )

print("i. Answer = 0.23530076631227745")
print(  )

print("j. Answer = 2.5946195882188348")
print(  )

print("k. Answer = 1.8775825618903734")
print(  )

print("l. Answer = 0.9166666666666666")
print(  )

# %% [markdown]
# # 2

# %%
# Create a variable x and assign it the value 0.05

# %%
# Update the value of x to equal 3x(1-x)

# %% [markdown]
# # 3

# %% [markdown]
# # 4
